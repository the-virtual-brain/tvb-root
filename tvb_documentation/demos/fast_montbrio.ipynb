# %%
# %pylab inline
from tvb.simulator.models import fast_montbrio
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nn = 96
w = np.random.randn(nn, nn)**2
d = np.random.rand(nn, nn)**2 * 19

# %%
tavg, bold = fast_montbrio.run_loop(w, d, total_time=30e3, tau=250.0, I=1.0, r_sigma=1e-4, V_sigma=1e-4)
subplot(311); plot(tavg[:,0,0]); ylabel('r')
subplot(312); plot(tavg[:,1,0]); ylabel('V')
subplot(313); plot(bold[:,0]); ylabel('BOLD')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1171/1171 [00:06<00:00, 194.80it/s]
# Text(0, 0.5, 'BOLD')
