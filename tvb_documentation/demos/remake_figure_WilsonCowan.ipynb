# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy

import tvb.simulator.lab as lab
from tvb.simulator.models.wilson_cowan import WilsonCowan
from tvb.simulator.plot.phase_plane_interactive import PhasePlaneInteractive

# %% [markdown]
# # Model of Wilson Cowan [WC_1972] and [WC_1973]
#
# The default parameters of the model are the same as parameters in the paper for the figure 4 of [WC_1972] :

# %%
wc = lab.models.WilsonCowan()
wc
# Out:
# <table>
# <h3>WilsonCowan</h3>
# <thead><tr><th></th><th style="text-align:left;width:40%">value</th></tr></thead>
# <tbody>
# <tr><td>P [min, median, max]</td><td style="text-align:left;"><pre>[0, 0, 0]</pre></td>
# <tr><td>P dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>P shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>Q [min, median, max]</td><td style="text-align:left;"><pre>[0, 0, 0]</pre></td>
# <tr><td>Q dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>Q shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>Type</td><td style="text-align:left;"><pre>WilsonCowan</pre></td>
# <tr><td>a_e [min, median, max]</td><td style="text-align:left;"><pre>[1.2, 1.2, 1.2]</pre></td>
# <tr><td>a_e dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>a_e shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>a_i [min, median, max]</td><td style="text-align:left;"><pre>[1, 1, 1]</pre></td>
# <tr><td>a_i dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>a_i shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>alpha_e [min, median, max]</td><td style="text-align:left;"><pre>[1, 1, 1]</pre></td>
# <tr><td>alpha_e dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>alpha_e shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>alpha_i [min, median, max]</td><td style="text-align:left;"><pre>[1, 1, 1]</pre></td>
# <tr><td>alpha_i dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>alpha_i shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>b_e [min, median, max]</td><td style="text-align:left;"><pre>[2.8, 2.8, 2.8]</pre></td>
# <tr><td>b_e dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>b_e shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>b_i [min, median, max]</td><td style="text-align:left;"><pre>[4, 4, 4]</pre></td>
# <tr><td>b_i dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>b_i shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>c_e [min, median, max]</td><td style="text-align:left;"><pre>[1, 1, 1]</pre></td>
# <tr><td>c_e dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>c_e shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>c_ee [min, median, max]</td><td style="text-align:left;"><pre>[12, 12, 12]</pre></td>
# <tr><td>c_ee dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>c_ee shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>c_ei [min, median, max]</td><td style="text-align:left;"><pre>[4, 4, 4]</pre></td>
# <tr><td>c_ei dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>c_ei shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>c_i [min, median, max]</td><td style="text-align:left;"><pre>[1, 1, 1]</pre></td>
# <tr><td>c_i dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>c_i shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>c_ie [min, median, max]</td><td style="text-align:left;"><pre>[13, 13, 13]</pre></td>
# <tr><td>c_ie dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>c_ie shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>c_ii [min, median, max]</td><td style="text-align:left;"><pre>[11, 11, 11]</pre></td>
# <tr><td>c_ii dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>c_ii shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>gid</td><td style="text-align:left;"><pre>UUID('3e063fe2-6189-48d0-89c6-8de6aedf59ae')</pre></td>
# <tr><td>k_e [min, median, max]</td><td style="text-align:left;"><pre>[1, 1, 1]</pre></td>
# <tr><td>k_e dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>k_e shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>k_i [min, median, max]</td><td style="text-align:left;"><pre>[1, 1, 1]</pre></td>
# <tr><td>k_i dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>k_i shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>r_e [min, median, max]</td><td style="text-align:left;"><pre>[1, 1, 1]</pre></td>
# <tr><td>r_e dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>r_e shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>r_i [min, median, max]</td><td style="text-align:left;"><pre>[1, 1, 1]</pre></td>
# <tr><td>r_i dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>r_i shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>shift_sigmoid dtype</td><td style="text-align:left;"><pre>bool</pre></td>
# <tr><td>shift_sigmoid shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>state_variable_range</td><td style="text-align:left;"><pre>{'E': array([0., 1.]), 'I': array([0., 1.])}</pre></td>
# <tr><td>tau_e [min, median, max]</td><td style="text-align:left;"><pre>[10, 10, 10]</pre></td>
# <tr><td>tau_e dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>tau_e shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>tau_i [min, median, max]</td><td style="text-align:left;"><pre>[10, 10, 10]</pre></td>
# <tr><td>tau_i dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>tau_i shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>theta_e [min, median, max]</td><td style="text-align:left;"><pre>[0, 0, 0]</pre></td>
# <tr><td>theta_e dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>theta_e shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>theta_i [min, median, max]</td><td style="text-align:left;"><pre>[0, 0, 0]</pre></td>
# <tr><td>theta_i dtype</td><td style="text-align:left;"><pre>float64</pre></td>
# <tr><td>theta_i shape</td><td style="text-align:left;"><pre>(1,)</pre></td>
# <tr><td>title</td><td style="text-align:left;"><pre>WilsonCowan gid: 3e063fe2-6189-48d0-89c6-8de6aedf59ae</pre></td>
# <tr><td>variables_of_interest</td><td style="text-align:left;"><pre>('E',)</pre></td>
# </tbody></table>

# %% [markdown]
# Without modifying the model, the phase plan is the same as the figure 4 of [WC_1972], pag. 10
# <img src="./figures/figure_4_wilson_1992.png" width="200" height="200">

# %%
ppi_fig=PhasePlaneInteractive(model=wc,integrator=lab.integrators.HeunDeterministic())
# configure the phase plane
# range for the axis
wc.state_variable_range['E'] = numpy.array([-0.1,0.5])
wc.state_variable_range['I'] = numpy.array([-0.1,0.5])
ppi_fig.show()
# change the axis of the phase plane
ppi_fig.update_svx('I')
ppi_fig.update_svy('E')
ppi_fig.calc_phase_plane()
ppi_fig.plot_phase_plane()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# # The derivate model of Wilson Cowan in [D_2011]

# %% [markdown]
# Change the parameters for reproducing Figure A1 in Daffertshofer and van Wijk (2011)

# %%
D_wc = lab.models.WilsonCowan()
D_wc.k_e = numpy.array([1.0])
D_wc.k_i = numpy.array([1.0])
D_wc.r_e = numpy.array([0.0])
D_wc.r_i = numpy.array([0.0])
D_wc.c_ee = numpy.array([10.0])
D_wc.c_ei = numpy.array([6.0])
D_wc.c_ie = numpy.array([10.0])
D_wc.c_ii = numpy.array([1.0])
D_wc.a_e = numpy.array([1.0])
D_wc.b_e = numpy.array([0.0])
D_wc.b_i = numpy.array([0.0])
D_wc.theta_e = numpy.array([2.0])
D_wc.theta_i = numpy.array([3.5])
D_wc.alpha_e = numpy.array([1.2])
D_wc.alpha_i = numpy.array([2.0])
D_wc.P = numpy.array([0.5])
D_wc.shift_sigmoid = numpy.array(False)

# %% [markdown]
# The phase plan are the same than the figure 4 of [D_2011]
# <img src="./figures/figure_A1_Daffertshofer_2011.jpg" width="300" height="200">

# %%
ppi_fig=PhasePlaneInteractive(model=D_wc,integrator=lab.integrators.HeunDeterministic())
# configure the phase plane
# range for the axis
D_wc.state_variable_range['E'] = numpy.array([0.,1.0])
D_wc.state_variable_range['I'] = numpy.array([0.,1.0])
ppi_fig.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## References
#
# [WC_1972] Wilson, H.R. and Cowan, J.D. *Excitatory and inhibitory
#     interactions in localized populations of model neurons*, Biophysical
#     journal, 12: 1-24, 1972.
# [WC_1973] Wilson, H.R. and Cowan, J.D  *A Mathematical Theory of the
#     Functional Dynamics of Cortical and Thalamic Nervous Tissue*
#
# [D_2011] Daffertshofer, A. and van Wijk, B. *On the influence of
#     amplitude on the connectivity between phases*
#     Frontiers in Neuroinformatics, July, 2011
